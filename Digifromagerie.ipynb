# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
DigiFromagerie = pd.read_csv("/content/dataw_fro03.csv")

DigiFromagerie.head()
# Out:
#    codcli genrecli    nomcli prenomcli  cpcli    villecli  codcde  \
# 0     446      Mme  CHRETIEN    Daniel  14540  BOURGUEBUS     478
# 1     446      Mme  CHRETIEN    Daniel  14540  BOURGUEBUS     478
# 2     446      Mme  CHRETIEN    Daniel  14540  BOURGUEBUS     478
# 3   17860       M.   VERARDO   Anthony  35400  SAINT MALO   21239
# 4    1330      Mme    ROBERT    Yvonne  61000     ALENCON    1386
#
#                 datcde  timbrecli  timbrecde  ...  qte  Colis  \
# 0  2004-10-22 00:00:00        5.0        4.8  ...  2.0    1.0
# 1  2004-10-22 00:00:00        5.0        4.8  ...  2.0    1.0
# 2  2004-10-22 00:00:00        5.0        4.8  ...  1.0    1.0
# 3  2006-10-03 00:00:00        0.0        3.9  ...  1.0    1.0
# 4  2004-11-23 00:00:00        4.0        6.5  ...  3.0    1.0
#
#              libobj   Tailleobj  Poidsobj  points  indispobj  \
# 0              Polo          XL       230    60.0          0
# 1     T-shirt Blanc           L       170    60.0          0
# ...

# %%
DigiFromagerie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135277 entries, 0 to 135276
# Data columns (total 25 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   codcli     135277 non-null  int64
#  1   genrecli   134552 non-null  object
#  2   nomcli     135277 non-null  object
#  3   prenomcli  134953 non-null  object
#  4   cpcli      135277 non-null  int64
#  5   villecli   135277 non-null  object
#  6   codcde     135277 non-null  int64
#  7   datcde     135275 non-null  object
#  8   timbrecli  135273 non-null  float64
#  9   timbrecde  135268 non-null  float64
#  10  Nbcolis    135269 non-null  float64
#  11  cheqcli    135234 non-null  float64
#  12  barchive   135277 non-null  int64
#  13  bstock     135277 non-null  int64
#  14  codobj     135277 non-null  int64
#  15  qte        135274 non-null  float64
#  16  Colis      135269 non-null  float64
#  17  libobj     135277 non-null  object
#  18  Tailleobj  48558 non-null   object
# ...

# %% [markdown]
# 1. **codcli** : Code client (numérique)
# 2. **genrecli** : Genre du client (texte, par exemple Mme)
# 3. **nomcli** : Nom du client (texte)
# 4. **prenomcli** : Prénom du client (texte)
# 5. **cpcli** : Code postal du client (numérique)
# 6. **villecli** : Ville du client (texte)
# 7. **codcde** : Code de la commande (numérique)
# 8. **datcde** : Date de la commande (datetime)
# 9. **timbrecli** : Timbre du client (numérique)
# 10. **timbrecde** : Timbre de la commande (numérique)
# 11. **Nbcolis** : Nombre de colis (numérique)
# 12. **cheqcli** : Chèque du client (numérique)
# 13. **barchive** : Indicateur d'archivage (numérique ou booléen)
# 14. **bstock** : Indicateur de stock (numérique ou booléen)
# 15. **codobj** : Code de l'objet (numérique)
# 16. **qte** : Quantité (numérique)
# 17. **Colis** : Colis (texte)
# 18. **libobj** : Libellé de l'objet (texte)
# 19. **Tailleobj** : Taille de l'objet (texte, par exemple XL)
# 20. **Poidsobj** : Poids de l'objet (numérique)
# 21. **points** : Points (numérique)
# 22. **indispobj** : Disponibilité de l'objet (numérique ou booléen)
# 23. **libcondit** : Libellé de la condition (texte)
# 24. **prixcond** : Prix de la condition (numérique)
# 25. **puobj** : Prix unitaire de l'objet (numérique)

# %%
DigiFromagerie.shape
# Out:
# (135277, 25)

# %%
#135052 APRES NETTOYE ET CONTRAINTES HBASE

# %%
DigiFromagerie.dtypes.transpose()
# Out:
# codcli         int64
# genrecli      object
# nomcli        object
# prenomcli     object
# cpcli          int64
# villecli      object
# codcde         int64
# datcde        object
# timbrecli    float64
# timbrecde    float64
# Nbcolis      float64
# cheqcli      float64
# barchive       int64
# bstock         int64
# codobj         int64
# qte          float64
# Colis        float64
# libobj        object
# Tailleobj     object
# Poidsobj       int64
# points       float64
# indispobj      int64
# libcondit     object
# prixcond       int64
# puobj          int64
# dtype: object

# %% [markdown]
# ##kpi
#
# Voir la fidélité des clients sur selon l’intervalle de dates
# • Voir le nombre d’objets commandés par année et les 5 meilleurs (Palmarès),
# • Voir les départements les plus représentatifs du programme de fidélité de la
# fromagerie (Palmarès).

# %%
DigiFromagerie.describe()
# Out:
#               codcli          cpcli         codcde      timbrecli  \
# count  135277.000000  135277.000000  135277.000000  135273.000000
# mean    19724.126097   48183.938807   56835.146832       0.113174
# std     12335.239240   20452.967226   20267.018358       0.760062
# min        27.000000    1120.000000     478.000000       0.000000
# 25%      8068.000000   28800.000000   42030.000000       0.000000
# 50%     19921.000000   50690.000000   58649.000000       0.000000
# 75%     30915.000000   61350.000000   72837.000000       0.000000
# max     41291.000000   95870.000000   90048.000000      20.250000
#
#            timbrecde        Nbcolis        cheqcli  barchive    bstock  \
# count  135268.000000  135269.000000  135234.000000  135277.0  135277.0
# mean        5.076906       1.017484       4.711951       1.0       1.0
# std         2.356537       0.151864       2.600960       0.0       0.0
# min         0.640000       1.000000       0.000000       1.0       1.0
# ...

# %%
#encoder utf 8
DigiFromagerie.to_csv('DigiFromagerie.csv', encoding='utf-8')

# %%
DigiFromagerie.to_csv('DigiFromagerie.csv', index=False)

# %%
#faire 4 kpi sur les données Voir la fidélité des clients sur selon l’intervalle de dates • Voir le nombre d’objets commandés par année et les 5 meilleurs (Palmarès), • Voir les départements les plus représentatifs du programme de fidélité de la fromagerie (Palmarès).
DigiFromagerie.head()
# Out:
#    codcli genrecli    nomcli prenomcli  cpcli    villecli  codcde  \
# 0     446      Mme  CHRETIEN    Daniel  14540  BOURGUEBUS     478
# 1     446      Mme  CHRETIEN    Daniel  14540  BOURGUEBUS     478
# 2     446      Mme  CHRETIEN    Daniel  14540  BOURGUEBUS     478
# 3   17860       M.   VERARDO   Anthony  35400  SAINT MALO   21239
# 4    1330      Mme    ROBERT    Yvonne  61000     ALENCON    1386
#
#                 datcde  timbrecli  timbrecde  ...  qte  Colis  \
# 0  2004-10-22 00:00:00        5.0        4.8  ...  2.0    1.0
# 1  2004-10-22 00:00:00        5.0        4.8  ...  2.0    1.0
# 2  2004-10-22 00:00:00        5.0        4.8  ...  1.0    1.0
# 3  2006-10-03 00:00:00        0.0        3.9  ...  1.0    1.0
# 4  2004-11-23 00:00:00        4.0        6.5  ...  3.0    1.0
#
#              libobj   Tailleobj  Poidsobj  points  indispobj  \
# 0              Polo          XL       230    60.0          0
# 1     T-shirt Blanc           L       170    60.0          0
# ...

# %%
#nettoyer pour power bi
DigiFromagerie.isnull().sum()
# Out:
# codcli           0
# genrecli       725
# nomcli           0
# prenomcli      324
# cpcli            0
# villecli         0
# codcde           0
# datcde           2
# timbrecli        4
# timbrecde        9
# Nbcolis          8
# cheqcli         43
# barchive         0
# bstock           0
# codobj           0
# qte              3
# Colis            8
# libobj           0
# Tailleobj    86719
# Poidsobj         0
# points         262
# indispobj        0
# libcondit        0
# prixcond         0
# puobj            0
# dtype: int64

# %%
#remplacer les valeurs manquantes par du vide
DigiFromagerie.fillna('', inplace=True)
# Out:
# <ipython-input-13-5eee965fbcc4>:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   DigiFromagerie.fillna('', inplace=True)

# %%
DigiFromagerie.isnull().sum()
# Out:
# codcli       0
# genrecli     0
# nomcli       0
# prenomcli    0
# cpcli        0
# villecli     0
# codcde       0
# datcde       0
# timbrecli    0
# timbrecde    0
# Nbcolis      0
# cheqcli      0
# barchive     0
# bstock       0
# codobj       0
# qte          0
# Colis        0
# libobj       0
# Tailleobj    0
# Poidsobj     0
# points       0
# indispobj    0
# libcondit    0
# prixcond     0
# puobj        0
# dtype: int64

# %%
DigiFromagerie.shape
# Out:
# (135277, 25)

# %%
#supprimer les doublons
DigiFromagerie.drop_duplicates(inplace=True)

# %%
DigiFromagerie.shape
# Out:
# (135218, 25)

# %%
digi = DigiFromagerie.copy()

# %%
digi.head()
# Out:
#    codcli genrecli    nomcli prenomcli  cpcli    villecli  codcde  \
# 0     446      Mme  CHRETIEN    Daniel  14540  BOURGUEBUS     478
# 1     446      Mme  CHRETIEN    Daniel  14540  BOURGUEBUS     478
# 2     446      Mme  CHRETIEN    Daniel  14540  BOURGUEBUS     478
# 3   17860       M.   VERARDO   Anthony  35400  SAINT MALO   21239
# 4    1330      Mme    ROBERT    Yvonne  61000     ALENCON    1386
#
#                 datcde timbrecli timbrecde  ...  qte Colis            libobj  \
# 0  2004-10-22 00:00:00       5.0       4.8  ...  2.0   1.0              Polo
# 1  2004-10-22 00:00:00       5.0       4.8  ...  2.0   1.0     T-shirt Blanc
# 2  2004-10-22 00:00:00       5.0       4.8  ...  1.0   1.0            Montre
# 3  2006-10-03 00:00:00       0.0       3.9  ...  1.0   1.0     T-shirt Blanc
# 4  2004-11-23 00:00:00       4.0       6.5  ...  3.0   1.0  Tete de menagere
#
#     Tailleobj  Poidsobj points indispobj                libcondit prixcond  \
# ...
